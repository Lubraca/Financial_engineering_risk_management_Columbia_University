# %% [markdown]
# <a href="https://colab.research.google.com/github/Lubraca/Financial_engineering_risk_management_Columbia_University/blob/main/Module_1/Statistics_review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git config --global user.name "Lubraca"
# !git config --global user.email "lucas.casarin@hotmail.com"

# %%
# !git clone https://github.com/Lubraca/Financial_engineering_risk_management_Columbia_University
# Out:
# Cloning into 'Financial_engineering_risk_management_Columbia_University'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), done.
